# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify duplicate values in the dataset.
#
# *   Remove duplicate values from the dataset.
#
# *   Identify missing values in the dataset.
#
# *   Impute the missing values in the dataset.
#
# *   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")
Survey_ConDta = df.copy()

# %%
Survey_ConDta.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  The quality of OSS and closed source software ...  Employed full-time
#
#           Country Student                                            EdLevel  \
# 0   United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1     New Zealand      No  Some college/university study without earning ...
# 2   United States      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3  United Kingdom      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4       Australia      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0  Computer science, computer engineering, or sof...  ...
# 1  Computer science, computer engineering, or sof...  ...
# 2  Computer science, computer engineering, or sof...  ...
# 3                                                NaN  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                               WelcomeChange  \
# 0   Just as welcome now as I felt last year
# 1   Just as welcome now as I felt last year
# 2  Somewhat more welcome now than last year
# 3   Just as welcome now as I felt last year
# 4   Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  22.0    Man    No
# 1                                                NaN  23.0    Man    No
# 2  Tech articles written by other developers;Cour...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  26.0    Man    No
# 4  Tech articles written by other developers;Indu...  29.0    Man    No
#
#                  Sexuality                              Ethnicity Dependents  \
# 0  Straight / Heterosexual           White or of European descent         No
# 1                 Bisexual           White or of European descent         No
# 2  Straight / Heterosexual           White or of European descent        Yes
# 3  Straight / Heterosexual           White or of European descent         No
# 4  Straight / Heterosexual  Hispanic or Latino/Latina;Multiracial         No
#
#             SurveyLength                  SurveyEase
# 0  Appropriate in length                        Easy
# 1  Appropriate in length  Neither easy nor difficult
# 2  Appropriate in length                        Easy
# 3  Appropriate in length  Neither easy nor difficult
# 4  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
# Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here

dupSurvey = df[df.duplicated()].sum()
dupSurvey

#print('Fetching {} from {}'.format(id, url))
print('{} is Number of Duplicates'.format(dupSurvey))
# Out:
# Respondent                                                       442786
# MainBranch            I am a developer by professionI am a developer...
# Hobbyist              YesYesYesYesYesNoNoYesYesYesNoYesYesYesYesYesY...
# OpenSourcer           Once a month or more oftenNeverLess than once ...
# OpenSource            OSS is, on average, of HIGHER quality than pro...
# Employment            Employed full-timeEmployed full-timeEmployed f...
# Country               United StatesUnited KingdomCanadaUnited States...
# EduOther              Received on-the-job training in software devel...
# YearsCode             1071211201968822637795483081594182684472012735...
# Age1stCode            1491511916181914915101417131413919918121516171...
# YearsCodePro          65634152361522843243208644102241172712Less tha...
# CareerSat             Very satisfiedVery satisfiedSlightly dissatisf...
# JobSat                Slightly satisfiedVery satisfiedSlightly satis...
# JobSeek               I’m not actively looking, but I am open to new...
# LastHireDate          1-2 years agoLess than a year agoLess than a y...
# FizzBuzz              YesNoNoNoNoYesYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoY...
# JobFactors            Specific department or team I'd be working on;...
# CurrencySymbol        USDGBPCADUSDGBPUSDINRUSDINRCADCADNZDDKKCADLKRC...
# CurrencyDesc          United States dollarPound sterlingCanadian dol...
# CompTotal                                                    36298584.0
# CompFreq              YearlyYearlyYearlyWeeklyYearlyYearlyYearlyMont...
# ConvertedComp                                                16657233.0
# WorkWeekHrs                                                      6206.0
# WorkRemote            A few days each monthA few days each monthLess...
# WorkLoc               HomeOfficeOfficeOfficeOfficeOfficeOfficeOffice...
# ImpSyn                A little above averageA little above averageA ...
# CodeRev               Yes, because I see value in code reviewYes, be...
# CodeRevHrs                                                       365.01
# UnitTests             Yes, it's not part of our process but the deve...
# PurchaseWhat          I have little or no influenceI have some influ...
# LanguageWorkedWith    C;C++;Go;HTML/CSS;JavaScript;SQL;TypeScriptBas...
# DevEnviron            Vim;Visual Studio CodeIntelliJ;Sublime TextNot...
# OpSys                 Linux-basedWindowsWindowsWindowsMacOSLinux-bas...
# Containers            Development;Testing;Production;Outside of work...
# ITperson              YesYesAlso YesYesSIGHYesYesSIGHAlso YesAlso Ye...
# OffOn                 YesYesYesYesYesYesYesYesYesYesYesYesYesYesYesW...
# Extraversion          OnlineOnlineIn real life (in person)In real li...
# SOVisit1st            2011201120122012201420102013201120122012201320...
# SOVisitFreq           Daily or almost dailyDaily or almost dailyDail...
# SOVisitTo             Find answers to specific questions;Contribute ...
# SOFindAnswer          1-2 times per week1-2 times per weekMore than ...
# SOAccount             YesYesYesNoNoYesNot sure / can't rememberYesYe...
# SOJobs                YesYesNo, I didn't know that Stack Overflow ha...
# EntTeams              No, I've heard of them, but I am not part of a...
# SOComm                Yes, somewhatYes, somewhatYes, somewhatYes, so...
# Age                                                              4359.0
# Trans                 NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# SurveyLength          Appropriate in lengthToo longAppropriate in le...
# SurveyEase            EasyEasyNeither easy nor difficultEasyEasyNeit...
# dtype: object is Number of Duplicates
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# your code goes here
# df.duplicated(subset=['brand'])
 #df[df.duplicated('Count_id')]

dupSurvey = df[df.duplicated(subset=['Respondent'], keep = False)]
dupSurvey

#print('Fetching {} from {}'.format(id, url))
#print('{} is Number of Duplicates'.format(dupSurvey))
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 1107        2339                     I am a developer by profession      Yes
# 1108        2342                     I am a developer by profession      Yes
# 1109        2343                     I am a developer by profession      Yes
# 1110        2344                     I am a developer by profession      Yes
# 1111        2347                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 2297        4674  I am not primarily a developer, but I write co...      Yes
# 2298        4675                     I am a developer by profession      Yes
# 2299        4676                     I am a developer by profession      Yes
# 2300        4677                     I am a developer by profession      Yes
# 2301        4679                     I am a developer by profession      Yes
#
#                                             OpenSourcer  \
# 1107                         Once a month or more often
# 1108                                              Never
# 1109  Less than once a month but more than once per ...
# 1110                                              Never
# 1111                                              Never
# ...                                                 ...
# 2297                            Less than once per year
# 2298                                              Never
# 2299                                              Never
# 2300                         Once a month or more often
# 2301  Less than once a month but more than once per ...
#
#                                              OpenSource          Employment  \
# 1107  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 1108  The quality of OSS and closed source software ...  Employed full-time
# 1109  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 1110  The quality of OSS and closed source software ...  Employed full-time
# 1111  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...                                                 ...                 ...
# 2297  The quality of OSS and closed source software ...  Employed full-time
# 2298  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 2299  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 2300  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 2301  The quality of OSS and closed source software ...  Employed full-time
#
#              Country Student  \
# 1107   United States      No
# 1108  United Kingdom      No
# 1109          Canada      No
# 1110   United States      No
# 1111  United Kingdom      No
# ...              ...     ...
# 2297      Bangladesh      No
# 2298   United States      No
# 2299         Finland      No
# 2300  United Kingdom      No
# 2301   United States      No
#
#                                                 EdLevel  \
# 1107  Some college/university study without earning ...
# 1108  Some college/university study without earning ...
# 1109        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1110           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1111        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...                                                 ...
# 2297           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2298           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2299        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 2300           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2301        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                          UndergradMajor  ...  \
# 1107  Computer science, computer engineering, or sof...  ...
# 1108  Information systems, information technology, o...  ...
# 1109  Computer science, computer engineering, or sof...  ...
# 1110  Computer science, computer engineering, or sof...  ...
# 1111  Computer science, computer engineering, or sof...  ...
# ...                                                 ...  ...
# 2297                                                NaN  ...
# 2298  Information systems, information technology, o...  ...
# 2299  Another engineering discipline (ex. civil, ele...  ...
# 2300  A natural science (ex. biology, chemistry, phy...  ...
# 2301  Computer science, computer engineering, or sof...  ...
#
#                                  WelcomeChange  \
# 1107   Just as welcome now as I felt last year
# 1108  Somewhat more welcome now than last year
# 1109  Somewhat more welcome now than last year
# 1110   Just as welcome now as I felt last year
# 1111   Just as welcome now as I felt last year
# ...                                        ...
# 2297  Somewhat less welcome now than last year
# 2298   Just as welcome now as I felt last year
# 2299  Somewhat less welcome now than last year
# 2300   Just as welcome now as I felt last year
# 2301   Just as welcome now as I felt last year
#
#                                            SONewContent   Age Gender Trans  \
# 1107                                                NaN  24.0    Man    No
# 1108  Tech meetups or events in your area;Courses on...  24.0    Man    No
# 1109  Tech articles written by other developers;Indu...  27.0    Man    No
# 1110  Tech articles written by other developers;Indu...  24.0    Man    No
# 1111                                                NaN   NaN  Woman    No
# ...                                                 ...   ...    ...   ...
# 2297  Tech articles written by other developers;Indu...  31.0    Man    No
# 2298                Tech meetups or events in your area  27.0    Man    No
# 2299                                                NaN  36.0    Man    No
# 2300                                                NaN  40.0    Man    No
# 2301                                                NaN  27.0    Man    No
#
#                                             Sexuality  \
# 1107                          Straight / Heterosexual
# 1108                          Straight / Heterosexual
# 1109                          Straight / Heterosexual
# 1110                          Straight / Heterosexual
# 1111                          Straight / Heterosexual
# ...                                               ...
# 2297  Bisexual;Gay or Lesbian;Straight / Heterosexual
# 2298                          Straight / Heterosexual
# 2299                          Straight / Heterosexual
# 2300                          Straight / Heterosexual
# 2301                                              NaN
#
#                                               Ethnicity Dependents  \
# 1107                       White or of European descent         No
# 1108                       White or of European descent         No
# 1109  Black or of African descent;White or of Europe...         No
# 1110                       White or of European descent         No
# 1111                                           Biracial         No
# ...                                                 ...        ...
# 2297  Black or of African descent;Hispanic or Latino...        Yes
# 2298                       White or of European descent         No
# 2299                       White or of European descent        Yes
# 2300                       White or of European descent        Yes
# 2301                       White or of European descent         No
#
#                SurveyLength                  SurveyEase
# 1107  Appropriate in length                        Easy
# 1108               Too long                        Easy
# 1109  Appropriate in length  Neither easy nor difficult
# 1110  Appropriate in length                        Easy
# 1111               Too long                        Easy
# ...                     ...                         ...
# 2297               Too long  Neither easy nor difficult
# 2298  Appropriate in length                        Easy
# 2299               Too long                        Easy
# 2300  Appropriate in length                        Easy
# 2301  Appropriate in length                        Easy
#
# [247 rows x 85 columns]

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here - https://www.geeksforgeeks.org/python-pandas-dataframe-drop_duplicates/
Survey_ConDta.drop_duplicates(inplace = True)
Survey_ConDta

#print('Fetching {} from {}'.format(id, url))
print("{} is remaining non-duplicated count".format(Survey_ConDta))
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# 3                                                  Never
# 4      Less than once a month but more than once per ...
# ...                                                  ...
# 11547                                              Never
# 11548                                              Never
# 11549                            Less than once per year
# 11550  Less than once a month but more than once per ...
# 11551  Less than once a month but more than once per ...
#
#                                               OpenSource          Employment  \
# 0      The quality of OSS and closed source software ...  Employed full-time
# 1      The quality of OSS and closed source software ...  Employed full-time
# 2      OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3      The quality of OSS and closed source software ...  Employed full-time
# 4      The quality of OSS and closed source software ...  Employed full-time
# ...                                                  ...                 ...
# 11547  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11548  The quality of OSS and closed source software ...  Employed full-time
# 11549  The quality of OSS and closed source software ...  Employed full-time
# 11550  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 11551  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#               Country Student  \
# 0       United States      No
# 1         New Zealand      No
# 2       United States      No
# 3      United Kingdom      No
# 4           Australia      No
# ...               ...     ...
# 11547   United States      No
# 11548          Poland      No
# 11549   United States      No
# 11550     Switzerland      No
# 11551  United Kingdom      No
#
#                                                  EdLevel  \
# 0               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1      Some college/university study without earning ...
# 2            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 11547        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11548        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11549        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11550  Secondary school (e.g. American high school, G...
# 11551          Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                                           UndergradMajor  ...  \
# 0      Computer science, computer engineering, or sof...  ...
# 1      Computer science, computer engineering, or sof...  ...
# 2      Computer science, computer engineering, or sof...  ...
# 3                                                    NaN  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 11547  Computer science, computer engineering, or sof...  ...
# 11548  Computer science, computer engineering, or sof...  ...
# 11549  Computer science, computer engineering, or sof...  ...
# 11550                                                NaN  ...
# 11551  A natural science (ex. biology, chemistry, phy...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2      Somewhat more welcome now than last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 11547   Just as welcome now as I felt last year
# 11548     A lot more welcome now than last year
# 11549     A lot more welcome now than last year
# 11550  Somewhat less welcome now than last year
# 11551   Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  22.0    Man    No
# 1                                                    NaN  23.0    Man    No
# 2      Tech articles written by other developers;Cour...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  26.0    Man    No
# 4      Tech articles written by other developers;Indu...  29.0    Man    No
# ...                                                  ...   ...    ...   ...
# 11547  Tech articles written by other developers;Cour...  36.0    Man    No
# 11548  Tech articles written by other developers;Tech...  25.0    Man    No
# 11549  Tech articles written by other developers;Indu...  34.0    Man    No
# 11550                                                NaN  25.0    Man    No
# 11551  Tech articles written by other developers;Tech...  30.0    Man    No
#
#                      Sexuality                              Ethnicity  \
# 0      Straight / Heterosexual           White or of European descent
# 1                     Bisexual           White or of European descent
# 2      Straight / Heterosexual           White or of European descent
# 3      Straight / Heterosexual           White or of European descent
# 4      Straight / Heterosexual  Hispanic or Latino/Latina;Multiracial
# ...                        ...                                    ...
# 11547  Straight / Heterosexual           White or of European descent
# 11548  Straight / Heterosexual           White or of European descent
# 11549  Straight / Heterosexual           White or of European descent
# 11550  Straight / Heterosexual           White or of European descent
# 11551                 Bisexual           White or of European descent
#
#       Dependents           SurveyLength                  SurveyEase
# 0             No  Appropriate in length                        Easy
# 1             No  Appropriate in length  Neither easy nor difficult
# 2            Yes  Appropriate in length                        Easy
# 3             No  Appropriate in length  Neither easy nor difficult
# 4             No  Appropriate in length                        Easy
# ...          ...                    ...                         ...
# 11547         No  Appropriate in length                   Difficult
# 11548         No  Appropriate in length  Neither easy nor difficult
# 11549        Yes               Too long                        Easy
# 11550         No  Appropriate in length                        Easy
# 11551         No  Appropriate in length                        Easy
#
# [11398 rows x 85 columns] is remaining non-duplicated count

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here

print("Number of Rows before Removing Duplicates: " + str(len(df)))
print("Number of Rows after Removing Duplicates: " + str(len(Survey_ConDta)))
# Out:
# Number of Rows before Removing Duplicates: 11552
# Number of Rows after Removing Duplicates: 11398

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here

Survey_ConDta.isnull()   #Returns df with null values represented as false
# Out:
#        Respondent  MainBranch  Hobbyist  OpenSourcer  OpenSource  Employment  \
# 0           False       False     False        False       False       False
# 1           False       False     False        False       False       False
# 2           False       False     False        False       False       False
# 3           False       False     False        False       False       False
# 4           False       False     False        False       False       False
# ...           ...         ...       ...          ...         ...         ...
# 11547       False       False     False        False       False       False
# 11548       False       False     False        False       False       False
# 11549       False       False     False        False       False       False
# 11550       False       False     False        False       False       False
# 11551       False       False     False        False       False       False
#
#        Country  Student  EdLevel  UndergradMajor  ...  WelcomeChange  \
# 0        False    False    False           False  ...          False
# 1        False    False    False           False  ...          False
# 2        False    False    False           False  ...          False
# 3        False    False    False            True  ...          False
# 4        False    False    False           False  ...          False
# ...        ...      ...      ...             ...  ...            ...
# 11547    False    False    False           False  ...          False
# 11548    False    False    False           False  ...          False
# 11549    False    False    False           False  ...          False
# 11550    False    False    False            True  ...          False
# 11551    False    False    False           False  ...          False
#
#        SONewContent    Age  Gender  Trans  Sexuality  Ethnicity  Dependents  \
# 0             False  False   False  False      False      False       False
# 1              True  False   False  False      False      False       False
# 2             False  False   False  False      False      False       False
# 3             False  False   False  False      False      False       False
# 4             False  False   False  False      False      False       False
# ...             ...    ...     ...    ...        ...        ...         ...
# 11547         False  False   False  False      False      False       False
# 11548         False  False   False  False      False      False       False
# 11549         False  False   False  False      False      False       False
# 11550          True  False   False  False      False      False       False
# 11551         False  False   False  False      False      False       False
#
#        SurveyLength  SurveyEase
# 0             False       False
# 1             False       False
# 2             False       False
# 3             False       False
# 4             False       False
# ...             ...         ...
# 11547         False       False
# 11548         False       False
# 11549         False       False
# 11550         False       False
# 11551         False       False
#
# [11398 rows x 85 columns]

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here

missWorkLoc = Survey_ConDta['WorkLoc'].isnull().sum()
print("Missing Values in WorkLoc Column is: " + str(missWorkLoc))
# Out:
# Missing Values in WorkLoc Column is: 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here

workLoc_ValCnt = Survey_ConDta['WorkLoc'].value_counts()   #number of unique WorkLoc values
workLoc_ValCnt   #.head(3)   - Long output
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference

maxWorkLoc_ValCnt = max(workLoc_ValCnt)
print("Maximum Occurring Word in WorkLoc Column: " + str(maxWorkLoc_ValCnt))
# Out:
# Maximum Occurring Word in WorkLoc Column: 6806

# %%
#df.fillna(df.mean())

#Survey_ConDta.fillna(Survey_ConDta['WorkLoc'] == maxWorkLoc_ValCnt) - no changes

# %%
Survey_ConDta['WorkLoc'].isnull().sum()
# Out:
# 32

# %%
#make a note of the majority value here, for future reference
#Survey_ConDta[Survey_ConDta['Workloc'] = [maxWorkLoc_ValCnt == max(workLoc_ValCnt)]]

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
"""
ReplceVal = Survey_ConDta[Survey_ConDta['WorkLoc'] == max(workLoc_ValCnt)]

Survey_ConDta['WorkLoc'].replace(np.nan, ReplceVal, inplace=True)
#Survey_ConDta['WorkLoc'].replace(np.nan, Survey_ConDta[Survey_ConDta['WorkLoc']==max(workLoc_ValCnt)], inplace=True)

Working Code
Survey_ConDta['WorkLoc'].replace(np.nan, "Office", inplace=True)
"""
Survey_ConDta['WorkLoc'] = Survey_ConDta['WorkLoc'].fillna(Survey_ConDta['WorkLoc'].mode().iloc[0])
#https://www.analyticsvidhya.com/blog/2021/04/how-to-handle-missing-values-of-categorical-variables/

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
Survey_ConDta['WorkLoc'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here

CompFreq_Cat = Survey_ConDta['CompFreq'].value_counts()   #number of unique WorkLoc values
CompFreq_Cat   #.head(3)   - Long output
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %%
Survey_ConDta['CompFreq'].isnull().sum()
# Out:
# 206

# %%
#Replace Missing Values for CompFreq & CompTotal

"""
ReplceVal = Survey_ConDta[Survey_ConDta['CompFreq']==max(CompFreq_Cat)].value

Survey_ConDta['CompFreq'].replace(np.nan, ReplceVal, inplace=True)
"""
Survey_ConDta['CompFreq'] = Survey_ConDta['CompFreq'].fillna(Survey_ConDta['CompFreq'].mode().iloc[0])
#https://www.analyticsvidhya.com/blog/2021/04/how-to-handle-missing-values-of-categorical-variables/

#Survey_ConDta['WorkLoc'].replace(np.nan, Survey_ConDta[Survey_ConDta['WorkLoc']==max(workLoc_ValCnt)], inplace=True)
#compFreq_ReplCompFreqey_ConDta['CompTotalCompFreq()Suvey_CompFreq_Cateq.value'].replace(np.nan, 'Yearly')

# %%
Survey_ConDta['CompFreq'].isnull().sum()
# Out:
# 0

# %%
Survey_ConDta['CompTotal'].isnull().sum()
# Out:
# 809

# %%
#df.fillna(df.mean())  - Another method
import numpy as np
compTot_Mean = Survey_ConDta['CompTotal'].mean()   #Cal mean
Survey_ConDta['CompTotal'] = Survey_ConDta['CompTotal'].replace(np.nan, compTot_Mean)

# %%
Survey_ConDta['CompTotal'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# your code goes here - https://www.dataquest.io/blog/tutorial-how-to-use-the-apply-method-in-pandas/
# Error Soln: https://stackoverflow.com/questions/70809477/valueerror-the-truth-value-of-a-series-is-ambiguous-use-a-empty-a-bool-a-i

#newdf['views'] = newdf.apply(lambda x: x['ENGAGEMENTS'] if ((x['PRODUCT'].upper()=='DISPLAY') & (x['COST_TYPE']=='CPE')) else x['views'], axis=1)
#Survey_ConDte['NormAnnComp'] = Survey_ConDta.apply(lambda x: x['CompTotal'] if ((x['CompFreq]=='Yearly' else x['views'], axis=1)

def StandAnnCompen(CompFreq, CompTotal):
    
    CompFreq_Cat = Survey_ConDta['CompFreq'].value_counts()   #number of unique WorkLoc values   

    if CompFreq_Cat == 'Monthly':
        Survey_ConDta['CompTotal']  = CompTotal * 12
    elif CompFreq_Cat == 'Weekly':
        Survey_ConDta['CompTotal'] = CompTotal * 52
    else:
        Survey_ConDta['CompTotal'] = CompTotal
    
    return Survey_ConDta['CompTotal']   #NormAnnComp

# %%
#Survey_ConDta['NormAnnComp'] = Survey_ConDta['CompFreq', 'CompTotal'].apply(StandAnnCompen)
#Survey_ConDta['NormAnnComp']

# %%
Survey_ConDat['NormalAnnualCompensation'] = Survey_ConDta.apply(lambda x: StandAnnCompen(x['CompFreq'], x['CompTotal']), axis=1)   #On each row
Survey_ConDta
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2344/238335289.py in <module>
# ----> 1 Survey_ConDat['NormalAnnualCompensation'] = Survey_ConDta.apply(lambda x: StandAnnCompen(x['CompFreq'], x['CompTotal']), axis=1)   #On each row
#       2 Survey_ConDta
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8739             kwargs=kwargs,
#    8740         )
# -> 8741         return op.apply()
#    8742
#    8743     def applymap(
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# /tmp/ipykernel_2344/238335289.py in <lambda>(x)
# ----> 1 Survey_ConDat['NormalAnnualCompensation'] = Survey_ConDta.apply(lambda x: StandAnnCompen(x['CompFreq'], x['CompTotal']), axis=1)   #On each row
#       2 Survey_ConDta
#
# /tmp/ipykernel_2344/1968311790.py in StandAnnCompen(CompFreq, CompTotal)
#       9     CompFreq_Cat = Survey_ConDta['CompFreq'].value_counts()   #number of unique WorkLoc values
#      10
# ---> 11     if CompFreq_Cat == 'Monthly':
#      12         Survey_ConDta['CompTotal']  = CompTotal * 12
#      13     elif CompFreq_Cat == 'Weekly':
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#USING LAMBDA WITH IF-ELSE CONSTRUCT
#df['Maths_spl Class'] = df["maths"].apply(lambda x: "No Need" if x>=5 elif x==5 "Hold" else "Need")
#https://www.geeksforgeeks.org/using-apply-in-pandas-lambda-functions-with-multiple-if-statements/

#lambda <args> : <return Value> if <condition > ( <return value > if <condition> else <return value>)

Survey_ConDta['NormalAnnualCompensation'] = Survey_ConDta['CompFreq'].apply(lambda x: CompTotal*12 if CompFreq_Cat == 'Monthly' else (CompTotal*52 if CompFreq_Cat == 'Weekly' else CompTotal))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2344/67588358.py in <module>
#       5 #lambda <args> : <return Value> if <condition > ( <return value > if <condition> else <return value>)
#       6
# ----> 7 Survey_ConDta['NormalAnnualCompensation'] = Survey_ConDta['CompFreq'].apply(lambda x: CompTotal*12 if CompFreq_Cat == 'Monthly' else (CompTotal*52 if CompFreq_Cat == 'Weekly' else CompTotal))
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
# -> 1102                     convert=self.convert_dtype,
#    1103                 )
#    1104
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_2344/67588358.py in <lambda>(x)
#       5 #lambda <args> : <return Value> if <condition > ( <return value > if <condition> else <return value>)
#       6
# ----> 7 Survey_ConDta['NormalAnnualCompensation'] = Survey_ConDta['CompFreq'].apply(lambda x: CompTotal*12 if CompFreq_Cat == 'Monthly' else (CompTotal*52 if CompFreq_Cat == 'Weekly' else CompTotal))
#
# NameError: name 'CompFreq_Cat' is not defined

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
